# %% [markdown]
# # (an unsuccessful try to) Classification masters-of-survival

# %% [markdown]
# ### import necessary libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import cv2
import os
import random
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split

# %%
labels_dict = dict()

# %%
labels_df = pd.read_csv("/kaggle/input/animal-categories-90-masters-of-survival/labels.csv")

# %%
for i in range(len(labels_df)):
    location_file,label = labels_df.iloc[i]
    try:
        labels_dict[label]
    except KeyError:
        labels_dict[label] = list()
        
    labels_dict[label].append(location_file)

# %%
min_count_of_categories = min([len(labels_dict[k]) for k in labels_dict.keys()])

# %%
X = []
y = []

for animal_category in labels_dict.keys():
    files_location = labels_dict[animal_category]
    for file_loc in files_location:
        image_array = cv2.imread("/kaggle/input/animal-categories-90-masters-of-survival/animals/animals/animals/"+file_loc,cv2.IMREAD_GRAYSCALE)
        image_array = cv2.resize(image_array,(256,256))
        image_array = image_array.flatten() 

        X.append(image_array)
        y.append(animal_category)

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.33, random_state=123)

# %%
knn = KNeighborsClassifier(n_neighbors=5)
knn.fit(X_train,y_train)
# Out:
# KNeighborsClassifier()

# %%
knn.score(X_train,y_train)
# Out:
# 0.4720840243228303

# %%
knn.score(X_test,y_test)
# Out:
# 0.22053872053872053

# %% [markdown]
# ### It seems that the similarity between parts of a class is very low.
